# %%
pip install kafka-python
# Out:
# Collecting kafka-python
#   Downloading kafka_python-2.0.2-py2.py3-none-any.whl.metadata (7.8 kB)
# Downloading kafka_python-2.0.2-py2.py3-none-any.whl (246 kB)
# Installing collected packages: kafka-python
# Successfully installed kafka-python-2.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install confluent-kafka
# Out:
# Collecting confluent-kafka
#   Using cached confluent_kafka-2.6.2.tar.gz (204 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: confluent-kafka
#   Building wheel for confluent-kafka (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for confluent-kafka (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [2112 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build/lib.linux-x86_64-cpython-38/confluent_kafka
#       copying src/confluent_kafka/deserializing_consumer.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka
#       copying src/confluent_kafka/serializing_producer.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka
#       copying src/confluent_kafka/__init__.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka
#       copying src/confluent_kafka/error.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka
#       creating build/lib.linux-x86_64-cpython-38/confluent_kafka/_model
#       copying src/confluent_kafka/_model/__init__.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/_model
#       creating build/lib.linux-x86_64-cpython-38/confluent_kafka/serialization
#       copying src/confluent_kafka/serialization/__init__.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/serialization
#       creating build/lib.linux-x86_64-cpython-38/confluent_kafka/_util
#       copying src/confluent_kafka/_util/validation_util.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/_util
#       copying src/confluent_kafka/_util/conversion_util.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/_util
#       copying src/confluent_kafka/_util/__init__.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/_util
#       creating build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry
#       copying src/confluent_kafka/schema_registry/wildcard_matcher.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry
#       copying src/confluent_kafka/schema_registry/rule_registry.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry
#       copying src/confluent_kafka/schema_registry/schema_registry_client.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry
#       copying src/confluent_kafka/schema_registry/mock_schema_registry_client.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry
#       copying src/confluent_kafka/schema_registry/serde.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry
#       copying src/confluent_kafka/schema_registry/__init__.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry
#       copying src/confluent_kafka/schema_registry/avro.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry
#       copying src/confluent_kafka/schema_registry/json_schema.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry
#       copying src/confluent_kafka/schema_registry/error.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry
#       copying src/confluent_kafka/schema_registry/protobuf.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry
#       creating build/lib.linux-x86_64-cpython-38/confluent_kafka/avro
#       copying src/confluent_kafka/avro/load.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/avro
#       copying src/confluent_kafka/avro/cached_schema_registry_client.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/avro
#       copying src/confluent_kafka/avro/__init__.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/avro
#       copying src/confluent_kafka/avro/error.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/avro
#       creating build/lib.linux-x86_64-cpython-38/confluent_kafka/admin
#       copying src/confluent_kafka/admin/_listoffsets.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/admin
#       copying src/confluent_kafka/admin/_metadata.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/admin
#       copying src/confluent_kafka/admin/_topic.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/admin
#       copying src/confluent_kafka/admin/_records.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/admin
#       copying src/confluent_kafka/admin/_resource.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/admin
#       copying src/confluent_kafka/admin/_scram.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/admin
#       copying src/confluent_kafka/admin/_acl.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/admin
#       copying src/confluent_kafka/admin/_group.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/admin
#       copying src/confluent_kafka/admin/_config.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/admin
#       copying src/confluent_kafka/admin/__init__.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/admin
#       copying src/confluent_kafka/admin/_cluster.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/admin
#       creating build/lib.linux-x86_64-cpython-38/confluent_kafka/kafkatest
#       copying src/confluent_kafka/kafkatest/verifiable_producer.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/kafkatest
#       copying src/confluent_kafka/kafkatest/__init__.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/kafkatest
#       copying src/confluent_kafka/kafkatest/verifiable_client.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/kafkatest
#       copying src/confluent_kafka/kafkatest/verifiable_consumer.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/kafkatest
#       creating build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules
#       copying src/confluent_kafka/schema_registry/rules/__init__.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules
#       creating build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/confluent
#       copying src/confluent_kafka/schema_registry/confluent/meta_pb2.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/confluent
#       copying src/confluent_kafka/schema_registry/confluent/__init__.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/confluent
#       creating build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/cel
#       copying src/confluent_kafka/schema_registry/rules/cel/cel_field_presence.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/cel
#       copying src/confluent_kafka/schema_registry/rules/cel/cel_executor.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/cel
#       copying src/confluent_kafka/schema_registry/rules/cel/__init__.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/cel
#       copying src/confluent_kafka/schema_registry/rules/cel/constraints.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/cel
#       copying src/confluent_kafka/schema_registry/rules/cel/string_format.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/cel
#       copying src/confluent_kafka/schema_registry/rules/cel/cel_field_executor.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/cel
#       copying src/confluent_kafka/schema_registry/rules/cel/extra_func.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/cel
#       creating build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/encryption
#       copying src/confluent_kafka/schema_registry/rules/encryption/encrypt_executor.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/encryption
#       copying src/confluent_kafka/schema_registry/rules/encryption/kms_driver_registry.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/encryption
#       copying src/confluent_kafka/schema_registry/rules/encryption/__init__.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/encryption
#       creating build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/jsonata
#       copying src/confluent_kafka/schema_registry/rules/jsonata/__init__.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/jsonata
#       copying src/confluent_kafka/schema_registry/rules/jsonata/jsonata_executor.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/jsonata
#       creating build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/encryption/azurekms
#       copying src/confluent_kafka/schema_registry/rules/encryption/azurekms/azure_client.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/encryption/azurekms
#       copying src/confluent_kafka/schema_registry/rules/encryption/azurekms/azure_driver.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/encryption/azurekms
#       copying src/confluent_kafka/schema_registry/rules/encryption/azurekms/azure_aead.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/encryption/azurekms
#       copying src/confluent_kafka/schema_registry/rules/encryption/azurekms/__init__.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/encryption/azurekms
#       creating build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/encryption/awskms
#       copying src/confluent_kafka/schema_registry/rules/encryption/awskms/aws_driver.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/encryption/awskms
#       copying src/confluent_kafka/schema_registry/rules/encryption/awskms/__init__.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/encryption/awskms
#       creating build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/encryption/localkms
#       copying src/confluent_kafka/schema_registry/rules/encryption/localkms/local_driver.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/encryption/localkms
#       copying src/confluent_kafka/schema_registry/rules/encryption/localkms/__init__.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/encryption/localkms
#       copying src/confluent_kafka/schema_registry/rules/encryption/localkms/local_client.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/encryption/localkms
#       creating build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/encryption/gcpkms
#       copying src/confluent_kafka/schema_registry/rules/encryption/gcpkms/gcp_driver.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/encryption/gcpkms
#       copying src/confluent_kafka/schema_registry/rules/encryption/gcpkms/gcp_client.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/encryption/gcpkms
#       copying src/confluent_kafka/schema_registry/rules/encryption/gcpkms/__init__.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/encryption/gcpkms
#       creating build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/encryption/hcvault
#       copying src/confluent_kafka/schema_registry/rules/encryption/hcvault/hcvault_client.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/encryption/hcvault
#       copying src/confluent_kafka/schema_registry/rules/encryption/hcvault/hcvault_driver.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/encryption/hcvault
#       copying src/confluent_kafka/schema_registry/rules/encryption/hcvault/__init__.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/encryption/hcvault
#       creating build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/encryption/dek_registry
#       copying src/confluent_kafka/schema_registry/rules/encryption/dek_registry/mock_dek_registry_client.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/encryption/dek_registry
#       copying src/confluent_kafka/schema_registry/rules/encryption/dek_registry/dek_registry_client.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/encryption/dek_registry
#       copying src/confluent_kafka/schema_registry/rules/encryption/dek_registry/__init__.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/rules/encryption/dek_registry
#       creating build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/confluent/types
#       copying src/confluent_kafka/schema_registry/confluent/types/decimal_pb2.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/confluent/types
#       copying src/confluent_kafka/schema_registry/confluent/types/__init__.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/schema_registry/confluent/types
#       creating build/lib.linux-x86_64-cpython-38/confluent_kafka/avro/serializer
#       copying src/confluent_kafka/avro/serializer/message_serializer.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/avro/serializer
#       copying src/confluent_kafka/avro/serializer/__init__.py -> build/lib.linux-x86_64-cpython-38/confluent_kafka/avro/serializer
#       running build_ext
#       building 'confluent_kafka.cimpl' extension
#       creating build/temp.linux-x86_64-cpython-38/tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src
#       gcc -pthread -B /home/ubuntu/anaconda3/envs/spark_start/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/home/ubuntu/anaconda3/envs/spark_start/include/python3.8 -c /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c -o build/temp.linux-x86_64-cpython-38/tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.o
#       In file included from /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:17:0:
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/confluent_kafka.h:66:2: error: #error "confluent-kafka-python requires librdkafka v2.6.1 or later. Install the latest version of librdkafka from the Confluent repositories, see http://docs.confluent.io/current/installation.html"
#        #error "confluent-kafka-python requires librdkafka v2.6.1 or later. Install the latest version of librdkafka from the Confluent repositories, see http://docs.confluent.io/current/installation.html"
#         ^~~~~
#       In file included from /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:17:0:
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/confluent_kafka.h:190:46: error: unknown type name ‘rd_kafka_error_t’; did you mean ‘rd_kafka_event_t’?
#        PyObject *KafkaError_new_from_error_destroy (rd_kafka_error_t *error);
#                                                     ^~~~~~~~~~~~~~~~
#                                                     rd_kafka_event_t
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/confluent_kafka.h:387:30: error: unknown type name ‘rd_kafka_Node_t’
#        PyObject *c_Node_to_py(const rd_kafka_Node_t *c_node);
#                                     ^~~~~~~~~~~~~~~
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/confluent_kafka.h:388:30: error: unknown type name ‘rd_kafka_Uuid_t’
#        PyObject *c_Uuid_to_py(const rd_kafka_Uuid_t *c_uuid);
#                                     ^~~~~~~~~~~~~~~
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/confluent_kafka.h:391:11: error: unknown type name ‘rd_kafka_topic_partition_result_t’
#            const rd_kafka_topic_partition_result_t **partition_results,
#                  ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/confluent_kafka.h:408:31: error: unknown type name ‘rd_kafka_consumer_group_metadata_t’
#        PyObject *c_cgmd_to_py (const rd_kafka_consumer_group_metadata_t *cgmd);
#                                      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/confluent_kafka.h:409:1: error: unknown type name ‘rd_kafka_consumer_group_metadata_t’; did you mean ‘rd_kafka_metadata_t’?
#        rd_kafka_consumer_group_metadata_t *py_to_c_cgmd (PyObject *obj);
#        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#        rd_kafka_metadata_t
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/confluent_kafka.h:503:3: error: unknown type name ‘rd_kafka_Uuid_t’
#          rd_kafka_Uuid_t *cUuid;
#          ^~~~~~~~~~~~~~~
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:82:9: error: unknown type name ‘rd_kafka_IsolationLevel_t’
#                rd_kafka_IsolationLevel_t isolation_level;
#                ^~~~~~~~~~~~~~~~~~~~~~~~~
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:83:9: error: unknown type name ‘rd_kafka_consumer_group_state_t’
#                rd_kafka_consumer_group_state_t* states;
#                ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:85:9: error: unknown type name ‘rd_kafka_consumer_group_type_t’
#                rd_kafka_consumer_group_type_t* types;
#                ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:120:8: error: unknown type name ‘rd_kafka_AdminOptions_t’
#        static rd_kafka_AdminOptions_t *
#               ^~~~~~~~~~~~~~~~~~~~~~~
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:121:35: error: unknown type name ‘rd_kafka_admin_op_t’; did you mean ‘rd_kafka_event_t’?
#        Admin_options_to_c (Handle *self, rd_kafka_admin_op_t for_api,
#                                          ^~~~~~~~~~~~~~~~~~~
#                                          rd_kafka_event_t
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:214:8: error: unknown type name ‘rd_kafka_AclBinding_t’
#        static rd_kafka_AclBinding_t *
#               ^~~~~~~~~~~~~~~~~~~~~
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c: In function ‘Admin_py_to_c_AclBinding’:
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:220:9: error: unknown type name ‘rd_kafka_AclBinding_t’; did you mean ‘rd_kafka_conf_t’?
#                rd_kafka_AclBinding_t *ret = NULL;
#                ^~~~~~~~~~~~~~~~~~~~~
#                rd_kafka_conf_t
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:230:27: warning: implicit declaration of function ‘rd_kafka_AclBinding_new’; did you mean ‘rd_kafka_conf_new’? [-Wimplicit-function-declaration]
#                            ret = rd_kafka_AclBinding_new(restype, resname, \
#                                  ^~~~~~~~~~~~~~~~~~~~~~~
#                                  rd_kafka_conf_new
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:230:25: warning: assignment makes pointer from integer without a cast [-Wint-conversion]
#                            ret = rd_kafka_AclBinding_new(restype, resname, \
#                                ^
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c: At top level:
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:243:8: error: unknown type name ‘rd_kafka_AclBindingFilter_t’
#        static rd_kafka_AclBindingFilter_t*
#               ^~~~~~~~~~~~~~~~~~~~~~~~~~~
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c: In function ‘Admin_py_to_c_AclBindingFilter’:
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:250:9: error: unknown type name ‘rd_kafka_AclBindingFilter_t’; did you mean ‘rd_kafka_conf_res_t’?
#                rd_kafka_AclBindingFilter_t* ret = NULL;
#                ^~~~~~~~~~~~~~~~~~~~~~~~~~~
#                rd_kafka_conf_res_t
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:259:27: warning: implicit declaration of function ‘rd_kafka_AclBindingFilter_new’; did you mean ‘rd_kafka_conf_dup_filter’? [-Wimplicit-function-declaration]
#                            ret = rd_kafka_AclBindingFilter_new(restype, resname, \
#                                  ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                                  rd_kafka_conf_dup_filter
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:259:25: warning: assignment makes pointer from integer without a cast [-Wint-conversion]
#                            ret = rd_kafka_AclBindingFilter_new(restype, resname, \
#                                ^
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c: In function ‘Admin_set_replica_assignment’:
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:333:31: warning: implicit declaration of function ‘rd_kafka_NewTopic_set_replica_assignment’; did you mean ‘Admin_set_replica_assignment’? [-Wimplicit-function-declaration]
#                                err = rd_kafka_NewTopic_set_replica_assignment(
#                                      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                                      Admin_set_replica_assignment
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:334:34: error: ‘rd_kafka_NewTopic_t’ undeclared (first use in this function); did you mean ‘rd_kafka_topic_t’?
#                                        (rd_kafka_NewTopic_t *)c_obj, (int32_t)pi,
#                                         ^~~~~~~~~~~~~~~~~~~
#                                         rd_kafka_topic_t
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:334:34: note: each undeclared identifier is reported only once for each function it appears in
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:334:55: error: expected expression before ‘)’ token
#                                        (rd_kafka_NewTopic_t *)c_obj, (int32_t)pi,
#                                                              ^
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:338:31: warning: implicit declaration of function ‘rd_kafka_NewPartitions_set_replica_assignment’; did you mean ‘Admin_set_replica_assignment’? [-Wimplicit-function-declaration]
#                                err = rd_kafka_NewPartitions_set_replica_assignment(
#                                      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                                      Admin_set_replica_assignment
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:339:34: error: ‘rd_kafka_NewPartitions_t’ undeclared (first use in this function); did you mean ‘rd_kafka_pause_partitions’?
#                                        (rd_kafka_NewPartitions_t *)c_obj, (int32_t)pi,
#                                         ^~~~~~~~~~~~~~~~~~~~~~~~
#                                         rd_kafka_pause_partitions
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:339:60: error: expected expression before ‘)’ token
#                                        (rd_kafka_NewPartitions_t *)c_obj, (int32_t)pi,
#                                                                   ^
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c: At top level:
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:364:31: error: unknown type name ‘rd_kafka_ConfigResource_t’; did you mean ‘rd_kafka_conf_res_t’?
#                                      rd_kafka_ConfigResource_t *c_obj,
#                                      ^~~~~~~~~~~~~~~~~~~~~~~~~
#                                      rd_kafka_conf_res_t
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c: In function ‘Admin_config_dict_to_c’:
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:494:31: warning: implicit declaration of function ‘rd_kafka_ConfigResource_set_config’; did you mean ‘rd_kafka_consume_stop’? [-Wimplicit-function-declaration]
#                                err = rd_kafka_ConfigResource_set_config(
#                                      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                                      rd_kafka_consume_stop
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:495:34: error: ‘rd_kafka_ConfigResource_t’ undeclared (first use in this function); did you mean ‘rd_kafka_conf_res_t’?
#                                        (rd_kafka_ConfigResource_t *)c_obj,
#                                         ^~~~~~~~~~~~~~~~~~~~~~~~~
#                                         rd_kafka_conf_res_t
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:495:61: error: expected expression before ‘)’ token
#                                        (rd_kafka_ConfigResource_t *)c_obj,
#                                                                    ^
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:498:31: warning: implicit declaration of function ‘rd_kafka_NewTopic_set_config’; did you mean ‘rd_kafka_topic_conf_get’? [-Wimplicit-function-declaration]
#                                err = rd_kafka_NewTopic_set_config(
#                                      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                                      rd_kafka_topic_conf_get
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:499:34: error: ‘rd_kafka_NewTopic_t’ undeclared (first use in this function); did you mean ‘rd_kafka_topic_t’?
#                                        (rd_kafka_NewTopic_t *)c_obj, k, v);
#                                         ^~~~~~~~~~~~~~~~~~~
#                                         rd_kafka_topic_t
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:499:55: error: expected expression before ‘)’ token
#                                        (rd_kafka_NewTopic_t *)c_obj, k, v);
#                                                              ^
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c: In function ‘Admin_create_topics’:
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:538:9: error: unknown type name ‘rd_kafka_AdminOptions_t’; did you mean ‘rd_kafka_topic_conf_t’?
#                rd_kafka_AdminOptions_t *c_options = NULL;
#                ^~~~~~~~~~~~~~~~~~~~~~~
#                rd_kafka_topic_conf_t
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:542:9: error: unknown type name ‘rd_kafka_NewTopic_t’; did you mean ‘rd_kafka_topic_t’?
#                rd_kafka_NewTopic_t **c_objs;
#                ^~~~~~~~~~~~~~~~~~~
#                rd_kafka_topic_t
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:565:21: warning: implicit declaration of function ‘Admin_options_to_c’; did you mean ‘Admin_options_def_cnt’? [-Wimplicit-function-declaration]
#                c_options = Admin_options_to_c(self, RD_KAFKA_ADMIN_OP_CREATETOPICS,
#                            ^~~~~~~~~~~~~~~~~~
#                            Admin_options_def_cnt
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:565:46: error: ‘RD_KAFKA_ADMIN_OP_CREATETOPICS’ undeclared (first use in this function); did you mean ‘RD_KAFKA_TIMESTAMP_CREATE_TIME’?
#                c_options = Admin_options_to_c(self, RD_KAFKA_ADMIN_OP_CREATETOPICS,
#                                                     ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                                                     RD_KAFKA_TIMESTAMP_CREATE_TIME
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:595:29: warning: implicit declaration of function ‘rd_kafka_NewTopic_new’; did you mean ‘rd_kafka_topic_new’? [-Wimplicit-function-declaration]
#                        c_objs[i] = rd_kafka_NewTopic_new(newt->topic,
#                                    ^~~~~~~~~~~~~~~~~~~~~
#                                    rd_kafka_topic_new
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:595:27: warning: assignment makes pointer from integer without a cast [-Wint-conversion]
#                        c_objs[i] = rd_kafka_NewTopic_new(newt->topic,
#                                  ^
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:645:16: warning: implicit declaration of function ‘rd_kafka_queue_get_background’; did you mean ‘rd_kafka_queue_get_partition’? [-Wimplicit-function-declaration]
#                rkqu = rd_kafka_queue_get_background(self->rk);
#                       ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                       rd_kafka_queue_get_partition
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:645:14: warning: assignment makes pointer from integer without a cast [-Wint-conversion]
#                rkqu = rd_kafka_queue_get_background(self->rk);
#                     ^
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:654:9: warning: implicit declaration of function ‘rd_kafka_CreateTopics’; did you mean ‘rd_kafka_queue_poll’? [-Wimplicit-function-declaration]
#                rd_kafka_CreateTopics(self->rk, c_objs, tcnt, c_options, rkqu);
#                ^~~~~~~~~~~~~~~~~~~~~
#                rd_kafka_queue_poll
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:657:9: warning: implicit declaration of function ‘rd_kafka_NewTopic_destroy_array’; did you mean ‘rd_kafka_topic_destroy’? [-Wimplicit-function-declaration]
#                rd_kafka_NewTopic_destroy_array(c_objs, tcnt);
#                ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                rd_kafka_topic_destroy
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:658:9: warning: implicit declaration of function ‘rd_kafka_AdminOptions_destroy’; did you mean ‘rd_kafka_topic_conf_destroy’? [-Wimplicit-function-declaration]
#                rd_kafka_AdminOptions_destroy(c_options);
#                ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                rd_kafka_topic_conf_destroy
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c: In function ‘Admin_delete_topics’:
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:687:9: error: unknown type name ‘rd_kafka_AdminOptions_t’; did you mean ‘rd_kafka_topic_conf_t’?
#                rd_kafka_AdminOptions_t *c_options = NULL;
#                ^~~~~~~~~~~~~~~~~~~~~~~
#                rd_kafka_topic_conf_t
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:690:9: error: unknown type name ‘rd_kafka_DeleteTopic_t’; did you mean ‘rd_kafka_topic_t’?
#                rd_kafka_DeleteTopic_t **c_objs;
#                ^~~~~~~~~~~~~~~~~~~~~~
#                rd_kafka_topic_t
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:708:46: error: ‘RD_KAFKA_ADMIN_OP_DELETETOPICS’ undeclared (first use in this function); did you mean ‘RD_KAFKA_VTYPE_TOPIC’?
#                c_options = Admin_options_to_c(self, RD_KAFKA_ADMIN_OP_DELETETOPICS,
#                                                     ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                                                     RD_KAFKA_VTYPE_TOPIC
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:738:29: warning: implicit declaration of function ‘rd_kafka_DeleteTopic_new’; did you mean ‘rd_kafka_topic_new’? [-Wimplicit-function-declaration]
#                        c_objs[i] = rd_kafka_DeleteTopic_new(
#                                    ^~~~~~~~~~~~~~~~~~~~~~~~
#                                    rd_kafka_topic_new
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:738:27: warning: assignment makes pointer from integer without a cast [-Wint-conversion]
#                        c_objs[i] = rd_kafka_DeleteTopic_new(
#                                  ^
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:748:14: warning: assignment makes pointer from integer without a cast [-Wint-conversion]
#                rkqu = rd_kafka_queue_get_background(self->rk);
#                     ^
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:757:9: warning: implicit declaration of function ‘rd_kafka_DeleteTopics’; did you mean ‘rd_kafka_queue_poll’? [-Wimplicit-function-declaration]
#                rd_kafka_DeleteTopics(self->rk, c_objs, tcnt, c_options, rkqu);
#                ^~~~~~~~~~~~~~~~~~~~~
#                rd_kafka_queue_poll
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:760:9: warning: implicit declaration of function ‘rd_kafka_DeleteTopic_destroy_array’; did you mean ‘rd_kafka_topic_destroy’? [-Wimplicit-function-declaration]
#                rd_kafka_DeleteTopic_destroy_array(c_objs, i);
#                ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                rd_kafka_topic_destroy
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c: In function ‘Admin_create_partitions’:
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:791:9: error: unknown type name ‘rd_kafka_AdminOptions_t’; did you mean ‘rd_kafka_topic_conf_t’?
#                rd_kafka_AdminOptions_t *c_options = NULL;
#                ^~~~~~~~~~~~~~~~~~~~~~~
#                rd_kafka_topic_conf_t
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:794:9: error: unknown type name ‘rd_kafka_NewPartitions_t’; did you mean ‘rd_kafka_topic_partition_t’?
#                rd_kafka_NewPartitions_t **c_objs;
#                ^~~~~~~~~~~~~~~~~~~~~~~~
#                rd_kafka_topic_partition_t
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:818:46: error: ‘RD_KAFKA_ADMIN_OP_CREATEPARTITIONS’ undeclared (first use in this function); did you mean ‘RD_KAFKA_RESP_ERR__REVOKE_PARTITIONS’?
#                c_options = Admin_options_to_c(self, RD_KAFKA_ADMIN_OP_CREATEPARTITIONS,
#                                                     ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                                                     RD_KAFKA_RESP_ERR__REVOKE_PARTITIONS
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:850:29: warning: implicit declaration of function ‘rd_kafka_NewPartitions_new’; did you mean ‘rd_kafka_pause_partitions’? [-Wimplicit-function-declaration]
#                        c_objs[i] = rd_kafka_NewPartitions_new(newp->topic,
#                                    ^~~~~~~~~~~~~~~~~~~~~~~~~~
#                                    rd_kafka_pause_partitions
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:850:27: warning: assignment makes pointer from integer without a cast [-Wint-conversion]
#                        c_objs[i] = rd_kafka_NewPartitions_new(newp->topic,
#                                  ^
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:875:14: warning: assignment makes pointer from integer without a cast [-Wint-conversion]
#                rkqu = rd_kafka_queue_get_background(self->rk);
#                     ^
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:884:9: warning: implicit declaration of function ‘rd_kafka_CreatePartitions’; did you mean ‘rd_kafka_resume_partitions’? [-Wimplicit-function-declaration]
#                rd_kafka_CreatePartitions(self->rk, c_objs, tcnt, c_options, rkqu);
#                ^~~~~~~~~~~~~~~~~~~~~~~~~
#                rd_kafka_resume_partitions
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:887:9: warning: implicit declaration of function ‘rd_kafka_NewPartitions_destroy_array’; did you mean ‘rd_kafka_topic_partition_destroy’? [-Wimplicit-function-declaration]
#                rd_kafka_NewPartitions_destroy_array(c_objs, tcnt);
#                ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                rd_kafka_topic_partition_destroy
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c: In function ‘Admin_describe_configs’:
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:917:9: error: unknown type name ‘rd_kafka_AdminOptions_t’; did you mean ‘rd_kafka_topic_conf_t’?
#                rd_kafka_AdminOptions_t *c_options = NULL;
#                ^~~~~~~~~~~~~~~~~~~~~~~
#                rd_kafka_topic_conf_t
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:920:9: error: unknown type name ‘rd_kafka_ConfigResource_t’; did you mean ‘rd_kafka_conf_res_t’?
#                rd_kafka_ConfigResource_t **c_objs;
#                ^~~~~~~~~~~~~~~~~~~~~~~~~
#                rd_kafka_conf_res_t
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:939:46: error: ‘RD_KAFKA_ADMIN_OP_DESCRIBECONFIGS’ undeclared (first use in this function); did you mean ‘RD_KAFKA_RESP_ERR_INVALID_CONFIG’?
#                c_options = Admin_options_to_c(self, RD_KAFKA_ADMIN_OP_DESCRIBECONFIGS,
#                                                     ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                                                     RD_KAFKA_RESP_ERR_INVALID_CONFIG
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:988:29: warning: implicit declaration of function ‘rd_kafka_ConfigResource_new’; did you mean ‘rd_kafka_queue_new’? [-Wimplicit-function-declaration]
#                        c_objs[i] = rd_kafka_ConfigResource_new(
#                                    ^~~~~~~~~~~~~~~~~~~~~~~~~~~
#                                    rd_kafka_queue_new
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:989:26: error: ‘rd_kafka_ResourceType_t’ undeclared (first use in this function); did you mean ‘rd_kafka_event_type_t’?
#                                (rd_kafka_ResourceType_t)restype, resname);
#                                 ^~~~~~~~~~~~~~~~~~~~~~~
#                                 rd_kafka_event_type_t
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:989:50: error: expected ‘)’ before ‘restype’
#                                (rd_kafka_ResourceType_t)restype, resname);
#                                                         ^~~~~~~
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:1003:14: warning: assignment makes pointer from integer without a cast [-Wint-conversion]
#                rkqu = rd_kafka_queue_get_background(self->rk);
#                     ^
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:1012:9: warning: implicit declaration of function ‘rd_kafka_DescribeConfigs’; did you mean ‘Admin_describe_configs’? [-Wimplicit-function-declaration]
#                rd_kafka_DescribeConfigs(self->rk, c_objs, cnt, c_options, rkqu);
#                ^~~~~~~~~~~~~~~~~~~~~~~~
#                Admin_describe_configs
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:1015:9: warning: implicit declaration of function ‘rd_kafka_ConfigResource_destroy_array’; did you mean ‘rd_kafka_queue_destroy’? [-Wimplicit-function-declaration]
#                rd_kafka_ConfigResource_destroy_array(c_objs, cnt);
#                ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                rd_kafka_queue_destroy
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c: In function ‘Admin_incremental_alter_configs’:
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:1045:9: error: unknown type name ‘rd_kafka_AdminOptions_t’; did you mean ‘rd_kafka_topic_conf_t’?
#                rd_kafka_AdminOptions_t *c_options = NULL;
#                ^~~~~~~~~~~~~~~~~~~~~~~
#                rd_kafka_topic_conf_t
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:1048:9: error: unknown type name ‘rd_kafka_ConfigResource_t’; did you mean ‘rd_kafka_conf_res_t’?
#                rd_kafka_ConfigResource_t **c_objs;
#                ^~~~~~~~~~~~~~~~~~~~~~~~~
#                rd_kafka_conf_res_t
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:1072:46: error: ‘RD_KAFKA_ADMIN_OP_INCREMENTALALTERCONFIGS’ undeclared (first use in this function); did you mean ‘RD_KAFKA_RESP_ERR_INVALID_CONFIG’?
#                c_options = Admin_options_to_c(self, RD_KAFKA_ADMIN_OP_INCREMENTALALTERCONFIGS,
#                                                     ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                                                     RD_KAFKA_RESP_ERR_INVALID_CONFIG
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:1131:26: error: ‘rd_kafka_ResourceType_t’ undeclared (first use in this function); did you mean ‘rd_kafka_event_type_t’?
#                                (rd_kafka_ResourceType_t)restype, resname);
#                                 ^~~~~~~~~~~~~~~~~~~~~~~
#                                 rd_kafka_event_type_t
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:1131:50: error: expected ‘)’ before ‘restype’
#                                (rd_kafka_ResourceType_t)restype, resname);
#                                                         ^~~~~~~
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:1149:22: warning: implicit declaration of function ‘Admin_incremental_config_to_c’; did you mean ‘Admin_incremental_alter_configs’? [-Wimplicit-function-declaration]
#                        if (!Admin_incremental_config_to_c(incremental_configs,
#                             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                             Admin_incremental_alter_configs
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:1162:14: warning: assignment makes pointer from integer without a cast [-Wint-conversion]
#                rkqu = rd_kafka_queue_get_background(self->rk);
#                     ^
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:1171:9: warning: implicit declaration of function ‘rd_kafka_IncrementalAlterConfigs’; did you mean ‘Admin_incremental_alter_configs’? [-Wimplicit-function-declaration]
#                rd_kafka_IncrementalAlterConfigs(self->rk, c_objs, cnt, c_options, rkqu);
#                ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                Admin_incremental_alter_configs
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c: In function ‘Admin_alter_configs’:
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:1211:9: error: unknown type name ‘rd_kafka_AdminOptions_t’; did you mean ‘rd_kafka_topic_conf_t’?
#                rd_kafka_AdminOptions_t *c_options = NULL;
#                ^~~~~~~~~~~~~~~~~~~~~~~
#                rd_kafka_topic_conf_t
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:1214:9: error: unknown type name ‘rd_kafka_ConfigResource_t’; did you mean ‘rd_kafka_conf_res_t’?
#                rd_kafka_ConfigResource_t **c_objs;
#                ^~~~~~~~~~~~~~~~~~~~~~~~~
#                rd_kafka_conf_res_t
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:1239:46: error: ‘RD_KAFKA_ADMIN_OP_ALTERCONFIGS’ undeclared (first use in this function); did you mean ‘RD_KAFKA_VTYPE_PARTITION’?
#                c_options = Admin_options_to_c(self, RD_KAFKA_ADMIN_OP_ALTERCONFIGS,
#                                                     ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                                                     RD_KAFKA_VTYPE_PARTITION
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:1290:26: error: ‘rd_kafka_ResourceType_t’ undeclared (first use in this function); did you mean ‘rd_kafka_event_type_t’?
#                                (rd_kafka_ResourceType_t)restype, resname);
#                                 ^~~~~~~~~~~~~~~~~~~~~~~
#                                 rd_kafka_event_type_t
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:1290:50: error: expected ‘)’ before ‘restype’
#                                (rd_kafka_ResourceType_t)restype, resname);
#                                                         ^~~~~~~
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:1319:14: warning: assignment makes pointer from integer without a cast [-Wint-conversion]
#                rkqu = rd_kafka_queue_get_background(self->rk);
#                     ^
# ...
#                        c_delete_groups_res = rd_kafka_event_DeleteGroups_result(rkev);
#                                              ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                                              rd_kafka_event_error_string
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:4959:37: warning: assignment makes pointer from integer without a cast [-Wint-conversion]
#                        c_delete_groups_res = rd_kafka_event_DeleteGroups_result(rkev);
#                                            ^
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:4962:25: warning: implicit declaration of function ‘rd_kafka_DeleteConsumerGroupOffsets_result_groups’ [-Wimplicit-function-declaration]
#                                rd_kafka_DeleteConsumerGroupOffsets_result_groups(
#                                ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:4961:47: warning: assignment makes pointer from integer without a cast [-Wint-conversion]
#                        c_delete_groups_res_responses =
#                                                      ^
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:4972:14: error: ‘RD_KAFKA_EVENT_LISTCONSUMERGROUPOFFSETS_RESULT’ undeclared (first use in this function); did you mean ‘RD_KAFKA_EVENT_LISTCONSUMERGROUPS_RESULT’?
#                case RD_KAFKA_EVENT_LISTCONSUMERGROUPOFFSETS_RESULT:
#                     ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                     RD_KAFKA_EVENT_LISTCONSUMERGROUPS_RESULT
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:4974:24: error: unknown type name ‘rd_kafka_ListConsumerGroupOffsets_result_t’
#                        const  rd_kafka_ListConsumerGroupOffsets_result_t *c_list_group_offset_res;
#                               ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:4975:23: error: unknown type name ‘rd_kafka_group_result_t’
#                        const rd_kafka_group_result_t **c_list_group_offset_res_responses;
#                              ^~~~~~~~~~~~~~~~~~~~~~~
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:4978:43: warning: implicit declaration of function ‘rd_kafka_event_ListConsumerGroupOffsets_result’; did you mean ‘Admin_c_ListConsumerGroupsResults_to_py’? [-Wimplicit-function-declaration]
#                        c_list_group_offset_res = rd_kafka_event_ListConsumerGroupOffsets_result(rkev);
#                                                  ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                                                  Admin_c_ListConsumerGroupsResults_to_py
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:4978:41: warning: assignment makes pointer from integer without a cast [-Wint-conversion]
#                        c_list_group_offset_res = rd_kafka_event_ListConsumerGroupOffsets_result(rkev);
#                                                ^
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:4981:25: warning: implicit declaration of function ‘rd_kafka_ListConsumerGroupOffsets_result_groups’; did you mean ‘Admin_c_ListConsumerGroupsResults_to_py’? [-Wimplicit-function-declaration]
#                                rd_kafka_ListConsumerGroupOffsets_result_groups(
#                                ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                                Admin_c_ListConsumerGroupsResults_to_py
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:4980:51: warning: assignment makes pointer from integer without a cast [-Wint-conversion]
#                        c_list_group_offset_res_responses =
#                                                          ^
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:4991:14: error: ‘RD_KAFKA_EVENT_ALTERCONSUMERGROUPOFFSETS_RESULT’ undeclared (first use in this function); did you mean ‘RD_KAFKA_EVENT_LISTCONSUMERGROUPOFFSETS_RESULT’?
#                case RD_KAFKA_EVENT_ALTERCONSUMERGROUPOFFSETS_RESULT:
#                     ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                     RD_KAFKA_EVENT_LISTCONSUMERGROUPOFFSETS_RESULT
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:4993:24: error: unknown type name ‘rd_kafka_AlterConsumerGroupOffsets_result_t’
#                        const  rd_kafka_AlterConsumerGroupOffsets_result_t *c_alter_group_offset_res;
#                               ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:4994:23: error: unknown type name ‘rd_kafka_group_result_t’
#                        const rd_kafka_group_result_t **c_alter_group_offset_res_responses;
#                              ^~~~~~~~~~~~~~~~~~~~~~~
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:4997:44: warning: implicit declaration of function ‘rd_kafka_event_AlterConsumerGroupOffsets_result’; did you mean ‘rd_kafka_get_watermark_offsets’? [-Wimplicit-function-declaration]
#                        c_alter_group_offset_res = rd_kafka_event_AlterConsumerGroupOffsets_result(rkev);
#                                                   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                                                   rd_kafka_get_watermark_offsets
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:4997:42: warning: assignment makes pointer from integer without a cast [-Wint-conversion]
#                        c_alter_group_offset_res = rd_kafka_event_AlterConsumerGroupOffsets_result(rkev);
#                                                 ^
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:5000:25: warning: implicit declaration of function ‘rd_kafka_AlterConsumerGroupOffsets_result_groups’ [-Wimplicit-function-declaration]
#                                rd_kafka_AlterConsumerGroupOffsets_result_groups(c_alter_group_offset_res,
#                                ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:4999:52: warning: assignment makes pointer from integer without a cast [-Wint-conversion]
#                        c_alter_group_offset_res_responses =
#                                                           ^
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:5009:14: error: ‘RD_KAFKA_EVENT_LISTOFFSETS_RESULT’ undeclared (first use in this function); did you mean ‘RD_KAFKA_EVENT_ALTERCONFIGS_RESULT’?
#                case RD_KAFKA_EVENT_LISTOFFSETS_RESULT:
#                     ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                     RD_KAFKA_EVENT_ALTERCONFIGS_RESULT
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:5012:23: error: unknown type name ‘rd_kafka_ListOffsets_result_t’
#                        const rd_kafka_ListOffsets_result_t *c_list_offsets_result = rd_kafka_event_ListOffsets_result(rkev);
#                              ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:5012:78: warning: implicit declaration of function ‘rd_kafka_event_ListOffsets_result’; did you mean ‘rd_kafka_event_message_count’? [-Wimplicit-function-declaration]
#                        const rd_kafka_ListOffsets_result_t *c_list_offsets_result = rd_kafka_event_ListOffsets_result(rkev);
#                                                                                     ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                                                                                     rd_kafka_event_message_count
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:5012:78: warning: initialization makes pointer from integer without a cast [-Wint-conversion]
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:5013:23: error: unknown type name ‘rd_kafka_ListOffsetsResultInfo_t’
#                        const rd_kafka_ListOffsetsResultInfo_t **c_result_infos = rd_kafka_ListOffsets_result_infos(
#                              ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:5013:75: warning: implicit declaration of function ‘rd_kafka_ListOffsets_result_infos’; did you mean ‘rd_kafka_offsets_for_times’? [-Wimplicit-function-declaration]
#                        const rd_kafka_ListOffsetsResultInfo_t **c_result_infos = rd_kafka_ListOffsets_result_infos(
#                                                                                  ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                                                                                  rd_kafka_offsets_for_times
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:5013:75: warning: initialization makes pointer from integer without a cast [-Wint-conversion]
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:5020:14: error: ‘RD_KAFKA_EVENT_DELETERECORDS_RESULT’ undeclared (first use in this function); did you mean ‘RD_KAFKA_EVENT_DELETEGROUPS_RESULT’?
#                case RD_KAFKA_EVENT_DELETERECORDS_RESULT:
#                     ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                     RD_KAFKA_EVENT_DELETEGROUPS_RESULT
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:5022:23: error: unknown type name ‘rd_kafka_DeleteRecords_result_t’
#                        const rd_kafka_DeleteRecords_result_t *c_delete_records_res = rd_kafka_event_DeleteRecords_result(rkev);
#                              ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:5022:79: warning: implicit declaration of function ‘rd_kafka_event_DeleteRecords_result’; did you mean ‘rd_kafka_event_error_string’? [-Wimplicit-function-declaration]
#                        const rd_kafka_DeleteRecords_result_t *c_delete_records_res = rd_kafka_event_DeleteRecords_result(rkev);
#                                                                                      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                                                                                      rd_kafka_event_error_string
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:5022:79: warning: initialization makes pointer from integer without a cast [-Wint-conversion]
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:5023:84: warning: implicit declaration of function ‘rd_kafka_DeleteRecords_result_offsets’; did you mean ‘rd_kafka_get_watermark_offsets’? [-Wimplicit-function-declaration]
#                        const rd_kafka_topic_partition_list_t *c_delete_records_res_list = rd_kafka_DeleteRecords_result_offsets(c_delete_records_res);
#                                                                                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                                                                                           rd_kafka_get_watermark_offsets
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:5023:84: warning: initialization makes pointer from integer without a cast [-Wint-conversion]
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:5029:14: error: ‘RD_KAFKA_EVENT_ELECTLEADERS_RESULT’ undeclared (first use in this function); did you mean ‘RD_KAFKA_EVENT_DELETEACLS_RESULT’?
#                case RD_KAFKA_EVENT_ELECTLEADERS_RESULT:
#                     ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                     RD_KAFKA_EVENT_DELETEACLS_RESULT
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:5033:23: error: unknown type name ‘rd_kafka_ElectLeaders_result_t’
#                        const rd_kafka_ElectLeaders_result_t
#                              ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:5035:25: warning: implicit declaration of function ‘rd_kafka_event_ElectLeaders_result’; did you mean ‘rd_kafka_event_message_count’? [-Wimplicit-function-declaration]
#                                rd_kafka_event_ElectLeaders_result(rkev);
#                                ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                                rd_kafka_event_message_count
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:5035:25: warning: initialization makes pointer from integer without a cast [-Wint-conversion]
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:5037:23: error: unknown type name ‘rd_kafka_topic_partition_result_t’
#                        const rd_kafka_topic_partition_result_t **partition_results =
#                              ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:5038:25: warning: implicit declaration of function ‘rd_kafka_ElectLeaders_result_partitions’; did you mean ‘rd_kafka_queue_get_partition’? [-Wimplicit-function-declaration]
#                                rd_kafka_ElectLeaders_result_partitions(
#                                ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                                rd_kafka_queue_get_partition
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:5038:25: warning: initialization makes pointer from integer without a cast [-Wint-conversion]
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c: In function ‘Admin_init’:
#       /tmp/pip-install-gkimqmmk/confluent-kafka_dfccb4d192d4432685c266505218549b/src/confluent_kafka/src/Admin.c:5152:9: warning: implicit declaration of function ‘rd_kafka_conf_set_background_event_cb’; did you mean ‘rd_kafka_conf_set_connect_cb’? [-Wimplicit-function-declaration]
#                rd_kafka_conf_set_background_event_cb(conf, Admin_background_event_cb);
#                ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                rd_kafka_conf_set_connect_cb
#       error: command '/usr/bin/gcc' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for confluent-kafka
# Failed to build confluent-kafka
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (confluent-kafka)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip show kafka-python
# Out:
# Name: kafka-python
# Version: 2.0.2
# Summary: Pure Python client for Apache Kafka
# Home-page: https://github.com/dpkp/kafka-python
# Author: Dana Powers
# Author-email: dana.powers@gmail.com
# License: Apache License 2.0
# Location: /home/ubuntu/anaconda3/envs/spark_start/lib/python3.8/site-packages
# Requires:
# Required-by:

# %%
topic = 'kafka-test'
kafka_server ='localhost:9092'

# %%
from kafka import KafkaProducer

# Kafka Producer 생성
producer = KafkaProducer(
    bootstrap_servers=kafka_server,  # Kafka 서버 주소
    value_serializer=lambda v: v.encode('utf-8')  # 메시지 직렬화
)

# 메시지 전송
for i in range(5):
    message = f"Message {i}"
    producer.send(topic, value=message)
    print(f"Sent: {message}")

# Producer 종료
producer.close()
# Out:
# Sent: Message 0
# Sent: Message 1
# Sent: Message 2
# Sent: Message 3
# Sent: Message 4

# %%
from kafka import KafkaConsumer

# Kafka Consumer 생성
consumer = KafkaConsumer(
    topic,  # 구독할 토픽 이름
    bootstrap_servers= kafka_server,  # Kafka 서버 주소
    group_id='test-group',  # 컨슈머 그룹 ID
    auto_offset_reset='earliest',  # 메시지를 처음부터 읽기
    enable_auto_commit=True,  # 자동 커밋 활성화
    value_deserializer=lambda x: x.decode('utf-8')  # 메시지 디코딩
)

print("Kafka Consumer 시작. 메시지 대기 중...")

try:
    for message in consumer:
        print(f"Received message: Key={message.key}, Value={message.value}")
except KeyboardInterrupt:
    print("Consumer 종료.")
finally:
    consumer.close()
# Out:
# Kafka Consumer 시작. 메시지 대기 중...
# Received message: Key=None, Value=\
# Received message: Key=None, Value=H
# Received message: Key=None, Value=
# Received message: Key=None, Value=hello
# Received message: Key=None, Value=hello2
# Received message: Key=None, Value=n
# Received message: Key=None, Value=Message 0
# Received message: Key=None, Value=Message 1
# Received message: Key=None, Value=Message 2
# Received message: Key=None, Value=Message 3
# Received message: Key=None, Value=Message 4

# %%
kafka.stop()
